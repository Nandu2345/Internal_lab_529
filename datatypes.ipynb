# %% [markdown]
# <a href="https://colab.research.google.com/github/Nandu2345/Internal_lab_529/blob/main/datatypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers= {10,20,30,40}
print("List:",numbers)
# Out:
# List: {40, 10, 20, 30}

# %%
fruits=["apple","banana"]
fruits.append("kiwi")
print(fruits)
fruits.remove("banana")
print(fruits)
fruits.insert(1,"berry")
print(fruits)
# Out:
# ['apple', 'banana', 'kiwi']
# ['apple', 'kiwi']
# ['apple', 'berry', 'kiwi']

# %% [markdown]
# # New section
